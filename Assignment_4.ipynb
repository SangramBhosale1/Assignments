# %%
1.  What exactly is []?
A.  In python, [] is used to create a list of items.

2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)
A.  ##Values assigned in spam
    spam= [2, 4, 6, 8, 10]
    ##The function append() will add the value to the existing list.
    spam.append('hello')
    print(spam)

3. What is the value of spam[int(int('3' * 2) / 11)]?
A.  spam=['a', 'b', 'c', 'd'] 
    spam[int(int('3' * 2) / 11)]
    ##Output is 'd'
    
4.  What is the value of spam[-1]?
A.  spam=['a', 'b', 'c', 'd']
    spam[-1]
    ##output is 'd'

5. What is the value of spam[:2]?
A.  spam=['a', 'b', 'c', 'd']
    spam[:2]
    ##output is ['a', 'b']
    
6.  What is the value of bacon.index('cat')?
A.  The value of bacon.index('cat') is 1.

7.  How does bacon.append(99) change the look of the list value in bacon?
A.  After running bacon.append(99) and calling variable bacon, the list will look as below:
    [3.14, 'cat', 11, 'cat', True, 99]
    
8.  How does bacon.remove('cat') change the look of the list in bacon?
A.  After running bacon.remove('cat') and calling variable bacon, the list will look as below:
    [3.14, 11, 'cat', True]
    ##The first occurence of string 'cat' at the index position 1 is removed.
    
9.  What are the list concatenation and list replication operators?
A.  Operator for list concatenation is +.
    Operator for list replication is *.
    
10.  What is difference between the list methods append() and insert()?
A.   Append() will add the given element at the end of the list.
     Eg:list=[1,2,3]
        a=[2,3]
        list.append(a)
        [1,2,3,[2,3]]
        
     Insert() will insert the given element at the specified position in the list.
     Eg:list=[1,2,3]
        a=[2,3]
        list.insert(2,a) ##Specified to insert at 2nd index position.
        [1,2,[2,3],3]
        
11. What are the two methods for removing items from a list?
A.  To remove items from a list:
    1.  Using the function remove():
        list=['air', 'water', 'ice', 'fire']
        list.remove('fire')
        list
        ##output after calling the variable list.
        ['air', 'water', 'ice']
    
    2.  Using the pop()
        list=['air', 'water', 'ice', 'fire']
        list.pop(2)##Specified the index position of the value to be removed.
        'ice'
        list
        ##output after calling the variable list.
        ['air', 'water', 'fire']
    
12.  Describe how list values and string values are identical.
A.   The list values and string values are identical as both are sequences.

13.  What's the difference between tuples and lists?
A.   The difference between tuples and lists is that tuples are immutable (are unchangeable) and lists are mutable (are changeable).

14.  How do you type a tuple value that only contains the integer 42?
A.   We add a comma after the integer 42. 
     Eg: a=(42,)
         type(a)
         tuple ##Output
        
15. How do you get a list value's tuple form? How do you get a tuple value's list form?
A.  Here, we use tuple() and list() functions.
    Eg: c=(1,2,3,4) ##tuple
        d=[5,6,7,8] ##list
        
        tuple(d)
        (5, 6, 7, 8) ##List converted to tuple.
        
        list(c)
        [1, 2, 3, 4] ##Tuple converted to list.

16.  Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
A.  Variable that contain list values are references.

17.  How do you distinguish between copy.copy() and copy.deepcopy()?
A.   The copy.copy() function will do a shallow copy, will not copy nested elements.
     The copy.deepcopy() will do a deep copy, will copy nested elements.
